# %% [markdown]
# See the agreement between DSC and subjective ratings

# %% [markdown]
# Managing dataframes

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np

# %%
dsc_df = pd.read_csv('/mnt/sda1/Repos/a-eye/Data/SHIP_dataset/new_manual_annotations/similarity/sim_manual_nnunet_N43.csv')
# dsc_df = pd.read_csv('/mnt/sda1/Repos/a-eye/Data/new_manual_annotations/similarity/sim_manual_atlas_N43.csv')

# %%
dsc_N4_df = dsc_df.iloc[:4]

# %%
# remove first 4 rows
# dsc_df = dsc_df.iloc[4:] # we don't have ratings of those 4 subjects
# reset index
# dsc_df = dsc_df.reset_index(drop=True)
# type string
dsc_df['Subject'] = dsc_df['Subject'].astype(str)

# %% [markdown]
# Statistics from dsc

# %%
# mean
dsc_mean = dsc_df['DSC_all'].mean()
print('Mean DSC_all:', dsc_mean)
# std
dsc_std = dsc_df['DSC_all'].std()
print('Std DSC_all:', dsc_std)
# variance
dsc_var = dsc_df['DSC_all'].var()
print('Variance DSC_all:', dsc_var)
# Out:
# Mean DSC_all: 0.7915975239280385
# Std DSC_all: 0.07554244353045286
# Variance DSC_all: 0.00570666077455166

# %% [markdown]
# Add those 4 subjects to the dataframe

# %%
# dsc_df = pd.concat(dsc_df, )

# %%
ratings_df = pd.read_excel('/mnt/sda1/Repos/a-eye/Output/mri_qc/scores.xlsx', sheet_name='brainmask_avg_data')
# remove '.nii.gz' for all the elements in column 'subject'
ratings_df['subject'] = ratings_df['subject'].str.replace('.nii.gz', '')
# Out:
# /tmp/ipykernel_1350402/1876439795.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   ratings_df['subject'] = ratings_df['subject'].str.replace('.nii.gz', '')

# %% [markdown]
# Add those 4 subjects to the dataframe

# %%
# add a row to ratings_df containing 'subject', and 'exclusion' 
ratings_df = ratings_df.append({'subject': '814997', 'rating': 3}, ignore_index=True)
ratings_df = ratings_df.append({'subject': '814999', 'rating': 3}, ignore_index=True)
ratings_df = ratings_df.append({'subject': '815173', 'rating': 2.5}, ignore_index=True)
ratings_df = ratings_df.append({'subject': '815262', 'rating': 3.3}, ignore_index=True)
# Out:
# /tmp/ipykernel_1350402/2636293913.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ratings_df = ratings_df.append({'subject': '814997', 'rating': 3}, ignore_index=True)
# /tmp/ipykernel_1350402/2636293913.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ratings_df = ratings_df.append({'subject': '814999', 'rating': 3}, ignore_index=True)
# /tmp/ipykernel_1350402/2636293913.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ratings_df = ratings_df.append({'subject': '815173', 'rating': 2.5}, ignore_index=True)
# /tmp/ipykernel_1350402/2636293913.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ratings_df = ratings_df.append({'subject': '815262', 'rating': 3.3}, ignore_index=True)

# %%
# combine both dataframes where the subject id matches: dsc_df['Subject'] == ratings_df['subject']
merged_df = dsc_df.merge(ratings_df, left_on='Subject', right_on='subject')

# %%
# only keep 'Subject', 'DSC_all', and 'rating' columns from merged_df
print(merged_df[['Subject', 'DSC_all', 'rating']])
# Out:
#           Subject   DSC_all  rating
# 0          814997  0.852391   3.000
# 1          814999  0.882686   3.000
# 2          815173  0.890689   2.500
# 3          815262  0.880808   3.300
# 4   2022160100011  0.853037   2.300
# 5   2022160100020  0.897414   2.600
# 6   2022160100071  0.890368   2.650
# 7   2022160100120  0.828213   2.625
# 8   2022160100247  0.856634   2.100
# 9   2022160100265  0.898847   1.125
# 10  2022160100273  0.856978   1.600
# 11  2022160100287  0.864858   1.475
# 12  2022160100381  0.796830   1.850
# 13  2022160100405  0.870213   2.975
# 14  2022160100441  0.823342   2.525
# 15  2022160100476  0.813537   2.825
# 16  2022160100484  0.823622   3.125
# 17  2022160100536  0.831841   1.975
# 18  2022160100544  0.811586   1.950
# 19  2022160100556  0.805807   1.250
# 20  2022160100895  0.846956   2.200
# 21  2022160100919  0.822525   2.425
# 22  2022160100945  0.826966   3.150
# 23  2022160100969  0.778202   1.250
# 24  2022160100984  0.723534   3.475
# 25  2022160101166  0.572995   1.025
# 26  2022160101197  0.764637   1.925
# 27  2022160101201  0.702629   1.625
# 28  2022160101217  0.775047   2.700
# 29  2022160101468  0.768820   2.950
# 30  2022160101853  0.686060   1.575
# 31  2022160101969  0.724348   3.450
# 32  2022160102121  0.797426   2.675
# 33  2022160102225  0.756283   3.325
# 34  2022160102274  0.750296   1.850
# 35  2022160102404  0.669640   2.800
# 36  2022160102428  0.754464   2.525
# 37  2022160102457  0.738029   2.075
# 38  2022160102578  0.742968   2.325
# 39  2022160102720  0.753784   2.425
# 40  2022160102790  0.631742   2.575
# 41  2022160102815  0.715780   1.500
# 42  2022160102891  0.705860   2.800

# %% [markdown]
# Plot

# %%
import plotly.express as px
from scipy.stats import shapiro

# normalize 'rating' column
# merged_df['rating'] = merged_df['rating'] / 4

# tissues
tissues = ['all','lens','globe','nerve','int_fat','ext_fat','lat_mus','med_mus','inf_mus','sup_mus']

# plot
for i in tissues:
    # check the normality of the data of DSC_i using Shapiro-Wilk test
    stat, p1 = shapiro(merged_df[f'DSC_{i}'])
    print(f'Statistics={stat}, p={p1}')
    # interpret
    alpha = 0.05
    if p1 > alpha:
        print(f'DSC_{i} sample looks Gaussian (fail to reject H0)')
    else:
        print(f'DSC_{i} sample does not look Gaussian (reject H0)')
    
    # check the normality of the data of rating using Shapiro-Wilk test
    stat, p2 = shapiro(merged_df['rating'])
    print(f'Statistics={stat}, p={p2}')
    # interpret
    alpha = 0.05
    if p2 > alpha:
        print(f'Rating sample looks Gaussian (fail to reject H0)')
    else:
        print(f'Rating sample does not look Gaussian (reject H0)')

    # compute r2 correlation between DSC_all and rating
    if p1 > alpha and p2 > alpha:
        print(f'Pearson correlation between DSC_{i} and rating: {merged_df[f"DSC_{i}"].corr(merged_df["rating"])}')
    else:
        print(f'Spearman correlation between DSC_{i} and rating: {merged_df[f"DSC_{i}"].corr(merged_df["rating"], method="spearman")}')

    print('\n')
    
    # plot
    fig = px.scatter(merged_df, x='rating', y=f'DSC_{i}')
    fig.update_layout(title=f'DSC_{i} vs Rating N={len(merged_df)}', xaxis_title='Rating', yaxis_title=f'DSC_{i}', xaxis_range=[0, 4], yaxis_range=[0, 1])
    # save as png
    # fig.write_image(f'/home/jaimebarranco/Desktop/new_manual_annotations/agreement_with_ratings/N43/atlas/DSC_{i}_vs_Rating.png')
    
    # fig.show()
# Out:
# Statistics=0.9543946385383606, p=0.08634490519762039
# DSC_all sample looks Gaussian (fail to reject H0)
# Statistics=0.9684348106384277, p=0.278981477022171
# Rating sample looks Gaussian (fail to reject H0)
# Pearson correlation between DSC_all and rating: 0.13974701224158975
#
#
# Statistics=0.8803253173828125, p=0.0003335998044349253
# DSC_lens sample does not look Gaussian (reject H0)
# Statistics=0.9684348106384277, p=0.278981477022171
# Rating sample looks Gaussian (fail to reject H0)
# Spearman correlation between DSC_lens and rating: 0.06268408891348133
#
#
# Statistics=0.7061105966567993, p=5.738618114037308e-08
# DSC_globe sample does not look Gaussian (reject H0)
# Statistics=0.9684348106384277, p=0.278981477022171
# Rating sample looks Gaussian (fail to reject H0)
# Spearman correlation between DSC_globe and rating: 0.24786648170366957
#
#
# Statistics=0.979572594165802, p=0.6307798624038696
# DSC_nerve sample looks Gaussian (fail to reject H0)
# Statistics=0.9684348106384277, p=0.278981477022171
# Rating sample looks Gaussian (fail to reject H0)
# Pearson correlation between DSC_nerve and rating: 0.0652995057733337
#
#
# Statistics=0.9341121315956116, p=0.016126176342368126
# DSC_int_fat sample does not look Gaussian (reject H0)
# Statistics=0.9684348106384277, p=0.278981477022171
# Rating sample looks Gaussian (fail to reject H0)
# Spearman correlation between DSC_int_fat and rating: 0.04025375830227175
#
#
# Statistics=0.9204580187797546, p=0.0055533298291265965
# DSC_ext_fat sample does not look Gaussian (reject H0)
# Statistics=0.9684348106384277, p=0.278981477022171
# Rating sample looks Gaussian (fail to reject H0)
# Spearman correlation between DSC_ext_fat and rating: 0.06774412982577441
#
#
# Statistics=0.8571154475212097, p=7.92458449723199e-05
# DSC_lat_mus sample does not look Gaussian (reject H0)
# Statistics=0.9684348106384277, p=0.278981477022171
# Rating sample looks Gaussian (fail to reject H0)
# Spearman correlation between DSC_lat_mus and rating: -0.1164564639814316
#
#
# Statistics=0.8240110278129578, p=1.2334110579104163e-05
# DSC_med_mus sample does not look Gaussian (reject H0)
# Statistics=0.9684348106384277, p=0.278981477022171
# Rating sample looks Gaussian (fail to reject H0)
# Spearman correlation between DSC_med_mus and rating: -0.012008156791859678
#
#
# Statistics=0.8929564952850342, p=0.0007702074944972992
# DSC_inf_mus sample does not look Gaussian (reject H0)
# Statistics=0.9684348106384277, p=0.278981477022171
# Rating sample looks Gaussian (fail to reject H0)
# Spearman correlation between DSC_inf_mus and rating: 0.18775017474568026
#
#
# Statistics=0.741204023361206, p=2.4160945599760453e-07
# DSC_sup_mus sample does not look Gaussian (reject H0)
# Statistics=0.9684348106384277, p=0.278981477022171
# Rating sample looks Gaussian (fail to reject H0)
# Spearman correlation between DSC_sup_mus and rating: 0.08443471253647244

# %% [markdown]
# p-values too!

# %%
import plotly.express as px
from scipy.stats import shapiro, pearsonr, spearmanr

# tissues
tissues = ['all','lens','globe','nerve','int_fat','ext_fat','lat_mus','med_mus','inf_mus','sup_mus']

for i in tissues:
    print(f'--- DSC_{i} ---')

    x = merged_df[f'DSC_{i}']
    y = merged_df['rating']

    # normality tests
    stat1, p1 = shapiro(x)
    stat2, p2 = shapiro(y)

    alpha = 0.05

    if p1 > alpha and p2 > alpha:
        # Pearson
        r, pval = pearsonr(x, y)
        method = 'Pearson'
    else:
        # Spearman
        r, pval = spearmanr(x, y)
        method = 'Spearman'

    print(f'Method: {method}')
    print(f'r = {r:.3f}, p-value = {pval:.3e}')
    print('\n')

    # plot
    fig = px.scatter(
        merged_df,
        x='rating',
        y=f'DSC_{i}',
        title=f'DSC_{i} vs Rating (N={len(merged_df)}) | r={r:.2f}, p={pval:.2e}'
    )
    fig.update_layout(
        xaxis_title='Rating',
        yaxis_title=f'DSC_{i}',
        xaxis_range=[0, 4],
        yaxis_range=[0, 1]
    )
    # fig.show()
# Out:
# --- DSC_all ---
# Method: Pearson
# r = 0.140, p-value = 3.714e-01
#
#
# --- DSC_lens ---
# Method: Spearman
# r = 0.063, p-value = 6.897e-01
#
#
# --- DSC_globe ---
# Method: Spearman
# r = 0.248, p-value = 1.090e-01
#
#
# --- DSC_nerve ---
# Method: Pearson
# r = 0.065, p-value = 6.774e-01
#
#
# --- DSC_int_fat ---
# Method: Spearman
# r = 0.040, p-value = 7.977e-01
#
#
# --- DSC_ext_fat ---
# Method: Spearman
# r = 0.068, p-value = 6.660e-01
#
#
# --- DSC_lat_mus ---
# Method: Spearman
# r = -0.116, p-value = 4.571e-01
#
#
# --- DSC_med_mus ---
# Method: Spearman
# r = -0.012, p-value = 9.391e-01
#
#
# --- DSC_inf_mus ---
# Method: Spearman
# r = 0.188, p-value = 2.280e-01
#
#
# --- DSC_sup_mus ---
# Method: Spearman
# r = 0.084, p-value = 5.904e-01
